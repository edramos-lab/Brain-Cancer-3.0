# %% [markdown]
# <a href="https://colab.research.google.com/github/edramos-lab/Brain-Cancer-3.0/blob/main/Brain_Cancer_3_1_SCRIPT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://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@github.com/edramos-lab/Brain-Cancer-3.0.git
# Out:
# Cloning into 'Brain-Cancer-3.0'...
# remote: Enumerating objects: 60, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 60 (delta 28), reused 31 (delta 12), pack-reused 0 (from 0)
# Receiving objects: 100% (60/60), 7.72 MiB | 26.44 MiB/s, done.
# Resolving deltas: 100% (28/28), done.

# %%
# !unzip /content/Brain-Cancer-3.0/BRATS_2019_Dataset.zip
# Out:
# Archive:  /content/Cancer-Brain-3.0/BRATS_2019_Dataset.zip
#   inflating: BRATS_2019_Dataset/testing/LGG_test/BraTS19_TCIA10_130_1_t1ce_slice107.jpg
#   inflating: BRATS_2019_Dataset/testing/HGG_test/Copia de BraTS19_2013_21_1_t1ce_slice94 (1).jpg
#   inflating: BRATS_2019_Dataset/testing/LGG_test/BraTS19_TCIA12_298_1_t1ce_slice50.jpg
#   inflating: BRATS_2019_Dataset/testing/LGG_test/BraTS19_TCIA12_466_1_t1ce_slice112.jpg
#   inflating: BRATS_2019_Dataset/testing/HGG_test/Copia de BraTS19_CBICA_AQQ_1_t1ce_slice48.jpg
#   inflating: BRATS_2019_Dataset/testing/LGG_test/BraTS19_TCIA09_255_1_t1ce_slice79.jpg
#   inflating: BRATS_2019_Dataset/testing/LGG_test/BraTS19_TCIA13_654_1_t1ce_slice74.jpg
#   inflating: BRATS_2019_Dataset/testing/LGG_test/BraTS19_TCIA12_298_1_t1ce_slice46.jpg
#   inflating: BRATS_2019_Dataset/testing/LGG_test/BraTS19_TCIA10_410_1_t1ce_slice104.jpg
#   inflating: BRATS_2019_Dataset/testing/LGG_test/BraTS19_TCIA13_634_1_t1ce_slice98.jpg
# ...

# %%
# !pip install -r /content/Brain-Cancer-3.0/requirements.txt

# %%
models =['deit3_base_patch16_224']#, 'swin_tiny_patch4_window7_224','convnextv2_tiny']#]#,'xception41','inception_v4','deit3_base_patch16_224',
lrs=[ 0.00001, 0.0001]
nsplitss=[3]
bss=[32]
subsets=[1]
for model in models:
  for lr in lrs:
    for nsplits in nsplitss:
      for bs in bss:
        for subset in subsets:
          # !python /content/Cancer-Brain-3.0/train.py --dataset_dir /content/BRATS_2019_Dataset/ --dataset_ratio {subset} --k_folds {nsplits} --lr {lr} --batch {bs} --epochs 10 --model {model} --project_name Cancer-Brain-3.1
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: edramos (Brain-Cancer). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.7
# wandb: Run data is saved locally in /content/wandb/run-20241130_005517-3s8y17mb
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run clear-plant-1692
# wandb: ⭐️ View project at https://wandb.ai/Brain-Cancer/Cancer-Brain-3.1
# wandb: 🚀 View run at https://wandb.ai/Brain-Cancer/Cancer-Brain-3.1/runs/3s8y17mb
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Generando Grad-CAM para una imagen del Fold 1...
# Generando Grad-CAM para la clase: LGG (índice 0)
# Figure(640x480)
# Generando Grad-CAM para la clase: HGG (índice 1)
# Figure(640x480)
# Figure(600x600)
# ...
