# %% [markdown]
# <a href="https://colab.research.google.com/github/edramos-lab/Cancer-Brain-3.0/blob/main/Cancer_Brain_3_0_SCRIPT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://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@github.com/edramos-lab/Cancer-Brain-3.0.git
# Out:
# Cloning into 'Cancer-Brain-3.0'...
# remote: Enumerating objects: 39, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 39 (delta 16), reused 22 (delta 7), pack-reused 0 (from 0)
# Receiving objects: 100% (39/39), 7.69 MiB | 6.64 MiB/s, done.
# Resolving deltas: 100% (16/16), done.

# %%
# !unzip /content/Cancer-Brain-3.0/BRATS_2019_Dataset.zip
# Out:
# Archive:  /content/Cancer-Brain-3.0/BRATS_2019_Dataset.zip
#   inflating: BRATS_2019_Dataset/testing/LGG_test/BraTS19_TCIA10_130_1_t1ce_slice107.jpg
#   inflating: BRATS_2019_Dataset/testing/HGG_test/Copia de BraTS19_2013_21_1_t1ce_slice94 (1).jpg
#   inflating: BRATS_2019_Dataset/testing/LGG_test/BraTS19_TCIA12_298_1_t1ce_slice50.jpg
#   inflating: BRATS_2019_Dataset/testing/LGG_test/BraTS19_TCIA12_466_1_t1ce_slice112.jpg
#   inflating: BRATS_2019_Dataset/testing/HGG_test/Copia de BraTS19_CBICA_AQQ_1_t1ce_slice48.jpg
#   inflating: BRATS_2019_Dataset/testing/LGG_test/BraTS19_TCIA09_255_1_t1ce_slice79.jpg
#   inflating: BRATS_2019_Dataset/testing/LGG_test/BraTS19_TCIA13_654_1_t1ce_slice74.jpg
#   inflating: BRATS_2019_Dataset/testing/LGG_test/BraTS19_TCIA12_298_1_t1ce_slice46.jpg
#   inflating: BRATS_2019_Dataset/testing/LGG_test/BraTS19_TCIA10_410_1_t1ce_slice104.jpg
#   inflating: BRATS_2019_Dataset/testing/LGG_test/BraTS19_TCIA13_634_1_t1ce_slice98.jpg
# ...

# %%
# !pip install -r /content/Cancer-Brain-3.0/requirements.txt

# %%
models =['efficientnet_b0', 'xception41']#, 'inception_v4','deit3_base_patch16_224', 'swin_tiny_patch4_window7_224','convnextv2_tiny']
lrs=[0.00001,0.0001,0.001]
nsplitss=[3,6]
bss=[32,64]
subsets=[0.25,0.5]
for model in models:
  for lr in lrs:
    for nsplits in nsplitss:
      for bs in bss:
        for subset in subsets:
          # !python /content/Cancer-Brain-3.0/train.py --dataset_dir /content/BRATS_2019_Dataset/ --dataset_ratio {subset} --k_folds {nsplits} --lr {lr} --batch {bs} --epochs 10 --model {model} --project_name Cancer-Brain-3.0
# Out:
# model.safetensors: 100% 21.4M/21.4M [00:00<00:00, 142MB/s]
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: 2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.18.6
# wandb: Run data is saved locally in /content/wandb/run-20241113_015948-oopgg2x5
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run pleasant-vortex-2
# ...
